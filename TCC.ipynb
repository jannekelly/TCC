# %% [markdown]
# <a href="https://colab.research.google.com/github/jannekelly/TCC/blob/Resultado-2/TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalando biblioteca para salvar o modelo em .h5

# %%
# !pip install pyyaml h5py  # Required to save models in HDF5 format
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (3.1.0)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from h5py) (1.19.5)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py) (1.5.2)

# %% [markdown]
# #Importando bibliotecas necessarias

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import os 
import cv2
import numpy as np

from keras.layers import Input,Lambda,Dense,Flatten
#from keras.models import Model, Sequential

#from keras.applications.vgg16 import VGG16, preprocess_input 
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input

# %% [markdown]
# #Autorizando acesso ao drive

# %%
from google.colab import drive
drive.mount('/content/drive')
#Clique no link a seguir para dar permissão ao colab para utilizar a conta drive, em seguida copie o código de autorização e cole no input requerido
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Augmentation

# %%
def reshape_dir_images(path_dir, shape=(150,150)):
    
    os.chdir(path_dir)
    
    for path_image in os.listdir(path_dir):
        
        img = cv2.imread(path_image)
        if img is None:#If the image data is empty, skip
            continue
            img_resize = cv2.resize(img, shape, interpolation=cv2.INTER_AREA)
            cv2.imwrite(path_image, img_resize)

# %%
def data_augmentation(list_paths, qtd_images_create=10):

    datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest')
    
    for path_class in list_paths:
        
        reshape_dir_images(path_dir=path_class, shape=(150,150)) # Fazendo o reshape
        
        os.chdir(path_class)
        for path_image in os.listdir(path_class):
            img = load_img(f"{path_image}")
            img_np = img_to_array(img) 
            img_np = img_np.reshape((1,) + img_np.shape)
            
            i = 0
            for batch in datagen.flow(img_np, batch_size=1,
                                  save_to_dir=".", save_prefix='aug', save_format='jpeg'):
                i += 1
                if i > qtd_images_create:     ## creates 10 image form 1 image 
                    break

# %%
paths_classes = [
    
    "/content/drive/My Drive/CNN-TCC/dataset_original/train/apple",
    "/content/drive/My Drive/CNN-TCC/dataset_original/train/banana",
    "/content/drive/My Drive/CNN-TCC/dataset_original/train/orange",
    
   

]

# %%
data_augmentation(paths_classes, qtd_images_create=10)

# %% [markdown]
# #Definindo o dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
   "/content/drive/My Drive/CNN-TCC/dataset_aumentado/train",
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(150,150),
  batch_size=512)
# Out:
# Found 29603 files belonging to 3 classes.
# Using 5920 files for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  "/content/drive/My Drive/CNN-TCC/dataset_aumentado/train",
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(150,150),
  batch_size=512)
# Out:
# Found 29603 files belonging to 3 classes.
# Using 23683 files for training.

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

# %% [markdown]
# #Criando o modelo

# %%
num_classes = 3

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3,activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes,activation='softmax')
])

model.build(input_shape=(None,150,150,3))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_1 (Rescaling)      (None, 150, 150, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 148, 148, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               2367616
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 2,391,587
# Trainable params: 2,391,587
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Modelo VGG16

# %%
### Defining Image size
IMAGE_SIZE = [150, 150]

### Loading model
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)


### Freezing layers
for layer in vgg.layers:  
    layer.trainable = False
    
### adding a 3 node final layer for predicion
#x = Flatten()(vgg.output)
#prediction = Dense(3, activation='softmax')(x)

model = Sequential(vgg.layers)
model.add(layers.experimental.preprocessing.Rescaling(1./255))
model.add(layers.Dropout(0.2))
model.add(layers.Flatten())
model.add(layers.Dense(3,activation='softmax'))
#model.add(layers.Dense(3, activation='relu'))

### Generating Summary
model.summary()

# %% [markdown]
# #Compilando e Treinando o Modelo

# %%
model.compile( loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),  
               optimizer='adam',  
               metrics=['accuracy'])

# %%
epochs=150

model_vgg = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/150
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4930: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`sparse_categorical_crossentropy` received `from_logits=True`, but '
# 47/47 [==============================] - 67s 1s/step - loss: 0.9338 - accuracy: 0.7483 - val_loss: 0.7117 - val_accuracy: 0.6775
# Epoch 2/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.2956 - accuracy: 0.8876 - val_loss: 0.2239 - val_accuracy: 0.9149
# Epoch 3/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.2205 - accuracy: 0.9223 - val_loss: 0.2486 - val_accuracy: 0.8981
# Epoch 4/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1911 - accuracy: 0.9340 - val_loss: 0.1488 - val_accuracy: 0.9505
# Epoch 5/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1942 - accuracy: 0.9315 - val_loss: 0.2796 - val_accuracy: 0.8973
# Epoch 6/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1561 - accuracy: 0.9469 - val_loss: 0.1131 - val_accuracy: 0.9635
# Epoch 7/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1174 - accuracy: 0.9614 - val_loss: 0.1048 - val_accuracy: 0.9635
# Epoch 8/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1122 - accuracy: 0.9613 - val_loss: 0.1064 - val_accuracy: 0.9605
# Epoch 9/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1115 - accuracy: 0.9622 - val_loss: 0.1499 - val_accuracy: 0.9503
# Epoch 10/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.1008 - accuracy: 0.9647 - val_loss: 0.1001 - val_accuracy: 0.9644
# Epoch 11/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0911 - accuracy: 0.9694 - val_loss: 0.1004 - val_accuracy: 0.9660
# Epoch 12/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0891 - accuracy: 0.9688 - val_loss: 0.0789 - val_accuracy: 0.9730
# Epoch 13/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0714 - accuracy: 0.9767 - val_loss: 0.0915 - val_accuracy: 0.9655
# Epoch 14/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0804 - accuracy: 0.9722 - val_loss: 0.0818 - val_accuracy: 0.9701
# Epoch 15/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0642 - accuracy: 0.9781 - val_loss: 0.0804 - val_accuracy: 0.9671
# Epoch 16/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0681 - accuracy: 0.9760 - val_loss: 0.0646 - val_accuracy: 0.9785
# Epoch 17/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0617 - accuracy: 0.9780 - val_loss: 0.0606 - val_accuracy: 0.9816
# Epoch 18/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0515 - accuracy: 0.9824 - val_loss: 0.0580 - val_accuracy: 0.9799
# Epoch 19/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0449 - accuracy: 0.9845 - val_loss: 0.0558 - val_accuracy: 0.9806
# Epoch 20/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0519 - accuracy: 0.9823 - val_loss: 0.0611 - val_accuracy: 0.9775
# Epoch 21/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0514 - accuracy: 0.9812 - val_loss: 0.0541 - val_accuracy: 0.9814
# Epoch 22/150
# 47/47 [==============================] - 63s 1s/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 0.0487 - val_accuracy: 0.9826
# Epoch 23/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0373 - accuracy: 0.9872 - val_loss: 0.0636 - val_accuracy: 0.9777
# Epoch 24/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0374 - accuracy: 0.9874 - val_loss: 0.0531 - val_accuracy: 0.9831
# Epoch 25/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0290 - accuracy: 0.9908 - val_loss: 0.0450 - val_accuracy: 0.9851
# Epoch 26/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0300 - accuracy: 0.9894 - val_loss: 0.0555 - val_accuracy: 0.9804
# Epoch 27/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.
150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0475 - val_accuracy: 0.9865
# Epoch 50/150
# 47/47 [==============================] - 66s 1s/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.0523 - val_accuracy: 0.9841
# Epoch 51/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.0478 - val_accuracy: 0.9858
# Epoch 52/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0405 - val_accuracy: 0.9882
# Epoch 53/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.0394 - val_accuracy: 0.9894
# Epoch 54/150
# 47/47 [==============================] - 63s 1s/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0434 - val_accuracy: 0.9885
# Epoch 55/150
# 47/47 [==============================] - 63s 1s/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.0403 - val_accuracy: 0.9894
# Epoch 56/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0411 - val_accuracy: 0.9897
# Epoch 57/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0447 - val_accuracy: 0.9892
# Epoch 58/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0441 - val_accuracy: 0.9902
# Epoch 59/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0888 - val_accuracy: 0.9812
# Epoch 60/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0997 - val_accuracy: 0.9782
# Epoch 61/150
# 47/47 [==============================] - 69s 1s/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.0546 - val_accuracy: 0.9882
# Epoch 62/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0276 - accuracy: 0.9908 - val_loss: 0.0677 - val_accuracy: 0.9812
# Epoch 63/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0220 - accuracy: 0.9924 - val_loss: 0.0614 - val_accuracy: 0.9828
# Epoch 64/150
# 47/47 [==============================] - 63s 1s/step - loss: 0.0148 - accuracy: 0.9955 - val_loss: 0.0822 - val_accuracy: 0.9821
# Epoch 65/150
# 47/47 [==============================] - 66s 1s/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0589 - val_accuracy: 0.9838
# Epoch 66/150
# 47/47 [==============================] - 66s 1s/step - loss: 0.0067 - accuracy: 0.9979 - val_loss: 0.0558 - val_accuracy: 0.9845
# Epoch 67/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0445 - val_accuracy: 0.9870
# Epoch 68/150
# 47/47 [==============================] - 68s 1s/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0431 - val_accuracy: 0.9892
# Epoch 69/150
# 47/47 [==============================] - 64s 1s/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.0500 - val_accuracy: 0.9858
# Epoch 70/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0120 - accuracy: 0.9965 - val_loss: 0.0493 - val_accuracy: 0.9861
# Epoch 71/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.0480 - val_accuracy: 0.9887
# Epoch 72/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0545 - val_accuracy: 0.9865
# Epoch 73/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0567 - val_accuracy: 0.9880
# Epoch 74/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0478 - val_accuracy: 0.9890
# Epoch 75/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.0430 - val_accuracy: 0.9895
# Epoch 76/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0486 - val_accuracy: 0.9890
# Epoch 77/150
# 47/47 [==============================] - 68s 1s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0481 - val_accuracy: 0.9875
# Epoch 78/150
# 47/47 [==============================] - 69s 1s/step - loss: 9.6602e-04 - accuracy: 0.9998 - val_loss: 0.0429 - val_accuracy: 0.9894
# Epoch 79/150
# 47/47 [==============================] - 69s 1s/step - loss: 5.3770e-04 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9878
# Epoch 80/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0637 - val_accuracy: 0.9853
# Epoch 81/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0648 - val_accuracy: 0.9856
# Epoch 82/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0257 - accuracy: 0.9929 - val_loss: 0.1067 - val_accuracy: 0.9824
# Epoch 83/150
# 47/47 [==============================] - 68s 1s/step - loss: 0.0478 - accuracy: 0.9877 - val_loss: 0.0864 - val_accuracy: 0.9791
# Epoch 84/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0544 - val_accuracy: 0.9875
# Epoch 85/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0587 - val_accuracy: 0.9872
# Epoch 86/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0500 - val_accuracy: 0.9885
# Epoch 87/150
# 47/47 [==============================] - 69s 1s/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 0.0536 - val_accuracy: 0.9878
# Epoch 88/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0503 - val_accuracy: 0.9883
# Epoch 89/150
# 47/47 [==============================] - 68s 1s/step - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.0530 - val_accuracy: 0.9872
# Epoch 90/150
# 47/47 [==============================] - 70s 1s/step - loss: 6.6150e-04 - accuracy: 0.9999 - val_loss: 0.0500 - val_accuracy: 0.9889
# Epoch 91/150
# 47/47 [==============================] - 71s 1s/step - loss: 9.1178e-04 - accuracy: 0.9999 - val_loss: 0.0534 - val_accuracy: 0.9877
# Epoch 92/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0021 - accuracy: 0.9995 - val_loss: 0.0535 - val_accuracy: 0.9894
# Epoch 93/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0512 - val_accuracy: 0.9885
# Epoch 94/150
# 47/47 [==============================] - 67s 1s/step - loss: 6.5254e-04 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9878
# Epoch 95/150
# 47/47 [==============================] - 68s 1s/step - loss: 4.7539e-04 - accuracy: 0.9999 - val_loss: 0.0525 - val_accuracy: 0.9890
# Epoch 96/150
# 47/47 [==============================] - 66s 1s/step - loss: 3.2453e-04 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9882
# Epoch 97/150
# 47/47 [==============================] - 82s 2s/step - loss: 4.0864e-04 - accuracy: 1.0000 - val_loss: 0.0539 - val_accuracy: 0.9889
# Epoch 98/150
# 47/47 [==============================] - 71s 1s/step - loss: 3.1479e-04 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9880
# Epoch 99/150
# 47/47 [==============================] - 66s 1s/step - loss: 4.6405e-04 - accuracy: 1.0000 - val_loss: 0.0559 - val_accuracy: 0.9882
# Epoch 100/150
# 47/47 [==============================] - 66s 1s/step - loss: 4.4899e-04 - accuracy: 0.9999 - val_loss: 0.0526 - val_accuracy: 0.9887
step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0437 - val_accuracy: 0.9890
# Epoch 121/150
# 47/47 [==============================] - 68s 1s/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.0459 - val_accuracy: 0.9889
# Epoch 122/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.0435 - val_accuracy: 0.9882
# Epoch 123/150
# 47/47 [==============================] - 65s 1s/step - loss: 9.3022e-04 - accuracy: 0.9999 - val_loss: 0.0481 - val_accuracy: 0.9890
# Epoch 124/150
# 47/47 [==============================] - 66s 1s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0453 - val_accuracy: 0.9889
# Epoch 125/150
# 47/47 [==============================] - 69s 1s/step - loss: 6.7799e-04 - accuracy: 0.9999 - val_loss: 0.0471 - val_accuracy: 0.9889
# Epoch 126/150
# 47/47 [==============================] - 68s 1s/step - loss: 6.3974e-04 - accuracy: 0.9999 - val_loss: 0.0452 - val_accuracy: 0.9899
# Epoch 127/150
# 47/47 [==============================] - 69s 1s/step - loss: 5.9044e-04 - accuracy: 0.9999 - val_loss: 0.0470 - val_accuracy: 0.9899
# Epoch 128/150
# 47/47 [==============================] - 69s 1s/step - loss: 3.9978e-04 - accuracy: 1.0000 - val_loss: 0.0477 - val_accuracy: 0.9894
# Epoch 129/150
# 47/47 [==============================] - 69s 1s/step - loss: 4.5884e-04 - accuracy: 1.0000 - val_loss: 0.0470 - val_accuracy: 0.9899
# Epoch 130/150
# 47/47 [==============================] - 69s 1s/step - loss: 5.1843e-04 - accuracy: 0.9999 - val_loss: 0.0477 - val_accuracy: 0.9889
# Epoch 131/150
# 47/47 [==============================] - 64s 1s/step - loss: 3.4108e-04 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9887
# Epoch 132/150
# 47/47 [==============================] - 69s 1s/step - loss: 4.2682e-04 - accuracy: 1.0000 - val_loss: 0.0494 - val_accuracy: 0.9892
# Epoch 133/150
# 47/47 [==============================] - 66s 1s/step - loss: 3.1974e-04 - accuracy: 0.9999 - val_loss: 0.0467 - val_accuracy: 0.9897
# Epoch 134/150
# 47/47 [==============================] - 70s 1s/step - loss: 6.4569e-04 - accuracy: 0.9999 - val_loss: 0.0560 - val_accuracy: 0.9873
# Epoch 135/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0493 - val_accuracy: 0.9894
# Epoch 136/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0599 - val_accuracy: 0.9883
# Epoch 137/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0021 - accuracy: 0.9992 - val_loss: 0.0580 - val_accuracy: 0.9877
# Epoch 138/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.0673 - val_accuracy: 0.9865
# Epoch 139/150
# 47/47 [==============================] - 66s 1s/step - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0602 - val_accuracy: 0.9880
# Epoch 140/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.0657 - val_accuracy: 0.9868
# Epoch 141/150
# 47/47 [==============================] - 69s 1s/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0703 - val_accuracy: 0.9853
# Epoch 142/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.0888 - val_accuracy: 0.9821
# Epoch 143/150
# 47/47 [==============================] - 69s 1s/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0742 - val_accuracy: 0.9858
# Epoch 144/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0076 - accuracy: 0.9978 - val_loss: 0.1013 - val_accuracy: 0.9845
# Epoch 145/150
# 47/47 [==============================] - 69s 1s/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.1204 - val_accuracy: 0.9801
# Epoch 146/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0180 - accuracy: 0.9941 - val_loss: 0.1024 - val_accuracy: 0.9823
# Epoch 147/150
# 47/47 [==============================] - 70s 1s/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0666 - val_accuracy: 0.9882
# Epoch 148/150
# 47/47 [==============================] - 65s 1s/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0667 - val_accuracy: 0.9873
# Epoch 149/150
# 47/47 [==============================] - 67s 1s/step - loss: 0.0020 - accuracy: 0.9995 - val_loss: 0.0556 - val_accuracy: 0.9883
# Epoch 150/150
# 47/47 [==============================] - 72s 1s/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0679 - val_accuracy: 0.9887

# %% [markdown]
# #Plotando dados de acurácia e loss

# %%
acc = model_vgg.history['accuracy']
val_acc = model_vgg.history['val_accuracy']

loss = model_vgg.history['loss']
val_loss = model_vgg.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(16,8))
#plt.subplot(1, 2, 1)
plt.style.use('bmh')
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
#plt.title('Accuracy')
plt.xlabel('Épocas')
plt.ylabel('Acurácia')
plt.show()
#plt.subplot(1, 2, 2)
plt.figure(figsize=(16,8))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
#plt.title('Training Loss')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.show()
acu=0
for i in val_acc:
  acu+= i
print((acu/len(val_acc))*100)
# Out:
# 98.06328888734181

# %% [markdown]
# #Testando o Modelo

# %%
class_names = train_ds.class_names
#print(class_names)

img = keras.preprocessing.image.load_img(
    "/content/drive/My Drive/CNN-TCC/dataset_original/test/apple/1.png", target_size=(150,150)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
plt.figure()
plt.plot()
img = plt.imread("/content/drive/My Drive/CNN-TCC/dataset_original/test/apple/1.png")
plt.imshow(np.squeeze(img))

title=class_names[np.argmax(score)]
plt.title(title, y=1.08)
print(
    "Esta imagem provavelmente pertence a classe {} com um confiança de {:.2f}%."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Esta imagem provavelmente pertence a classe apple com um confiança de 57.61%.

# %%
img = keras.preprocessing.image.load_img(
    "/content/drive/My Drive/CNN-TCC/dataset_original/test/banana/29.png", target_size=(150,150)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
plt.figure()
plt.plot()
img = plt.imread("/content/drive/My Drive/CNN-TCC/dataset_original/test/banana/29.png")
plt.imshow(np.squeeze(img))

title=class_names[np.argmax(score)]
plt.title(title, y=1.08)
print(
    "Esta imagem provavelmente pertence a classe {} com um confiança de {:.2f}%."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Esta imagem provavelmente pertence a classe banana com um confiança de 57.61%.

# %%
img = keras.preprocessing.image.load_img(
    "/content/drive/My Drive/CNN-TCC/dataset_original/test/orange/29.png", target_size=(150,150)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)
predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])
plt.figure()
plt.plot()
img = plt.imread("/content/drive/My Drive/CNN-TCC/dataset_original/test/orange/29.png")
plt.imshow(np.squeeze(img))

title=class_names[np.argmax(score)]
plt.title(title, y=1.08)
print(
    "Esta imagem provavelmente pertence a classe {} com um confiança de {:.2f}%."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# Esta imagem provavelmente pertence a classe orange com um confiança de 57.21%.

# %% [markdown]
# #Salvando o Modelo .h5

# %%
model.save('/content/drive/My Drive/CNN-TCC/data/model_aume_frutas.h5')

# %% [markdown]
# #Testes

# %%
import os
import numpy as np

import tensorflow.keras
from PIL import Image, ImageOps
import numpy as np

def model_predict(img_path):
    np.set_printoptions(suppress=True)
    
    # Create the array of the right shape to feed into the keras model
    # The 'length' or number of images you can put into the array is
    # determined by the first position in the shape tuple, in this case 1.
    data = np.ndarray(shape=(1, 150, 150, 3), dtype=np.float32)
    
    # Replace this with the path to your image
    image = Image.open(img_path)
    #resizing the image to be at least 150x150
    
    size = (150, 150)
    image = ImageOps.fit(image, size, Image.ANTIALIAS)
    
    #turn the image into a numpy array
    image_array = np.asarray(image)
    
    # Normalize the image
    normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
    
    # Load the image into the array
    data[0] = normalized_image_array
    
        
    # Load the model
    model = tensorflow.keras.models.load_model('/content/drive/My Drive/CNN-TCC/data/model_frutas.h5')
    _,acc=model.evaluate(test_set,test_datagen)
    
    # run the inference
    
    preds = ""
    prediction = model.predict(data)
    
    if np.argmax(prediction)==2:
        preds = "laranja"
    elif np.argmax(prediction)==0:
        preds = "apple"
    elif np.argmax(prediction)==1:
        preds = "banana"

    return preds,acc

# %%
#from keras.preprocessing import image
def _LoadImage(filePath):
  test_image = image.load_img(filePath, target_size = (150,150))
  test_image = image.img_to_array(test_image)
  test_image = np.expand_dims(test_image, axis=0)
  return test_image
test_this = _LoadImage("/content/drive/My Drive/CNN-TCC/data/test/apple/1.png")


result = model.predict(test_this)
print(result)
# Out:
# [[1. 0. 0.]]

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot()
img = plt.imread("/content/drive/My Drive/CNN-TCC/data/test/orange/1.png")
plt.imshow(np.squeeze(img))

title=model_predict("/content/drive/My Drive/CNN-TCC/data/test/orange/1.png")
plt.title(title, y=1.08)

plt.figure()
plt.plot()
img1 = plt.imread("/content/drive/My Drive/CNN-TCC/data/test/banana/1.png")
plt.imshow(np.squeeze(img1))
title1=model_predict("/content/drive/My Drive/CNN-TCC/data/test/banana/1.png")
plt.title(title1,y=1.08)

plt.figure()
plt.plot()
img2 = plt.imread("/content/drive/My Drive/CNN-TCC/data/test/apple/1.png")
plt.imshow(np.squeeze(img2))
title2=model_predict("/content/drive/My Drive/CNN-TCC/data/test/apple/1.png")
plt.title(title2, y=1.08)
# Out:
# Text(0.5, 1.08, 'apple')

# %%
 import numpy as np
 from sklearn.metrics import *

 dx = 5
 xx = np.argmax(img2,axis=1)[:5]
 yy = np.argmax(test_data ,axis = 1)[:5]
 print(xx)
 print(yy)
 #print('computed AUC using sklearn.metrics.auc: {}'.format(auc(xx,yy)))
 #print('computed AUC using np.trapz: {}'.format(np.trapz(yy, dx = dx)))
